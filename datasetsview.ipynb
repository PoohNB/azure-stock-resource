# %%
import pandas as pd

df = pd.read_csv('datasets/bbc_news.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42115 entries, 0 to 42114
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        42115 non-null  object
#  1   pubDate      42115 non-null  object
#  2   guid         42115 non-null  object
#  3   link         42115 non-null  object
#  4   description  42115 non-null  object
# dtypes: object(5)
# memory usage: 1.6+ MB

# %%
keywords = r"tesla|model [3syx]|cybertruck|musk"
df_tesla = df[df['title'].str.contains(keywords, case=False, na=False, regex=True)]
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 138 entries, 1340 to 42099
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        138 non-null    object
#  1   pubDate      138 non-null    object
#  2   guid         138 non-null    object
#  3   link         138 non-null    object
#  4   description  138 non-null    object
# dtypes: object(5)
# memory usage: 6.5+ KB

# %%
df_tesla.head(10)
# Out:
#                                                   title  \
# 1340            What are Elon Musk's plans for Twitter?
# 1573  Elon Musk will now not join Twitter's board, C...
# 1738  Elon Musk 'not sure' his takeover bid for Twit...
# 1785       Twitter board takes action to fight Musk bid
# 1937           Tesla profits soar as customers pay more
# 2135    Elon Musk strikes deal to buy Twitter for $44bn
# 2148  The Papers: 'Musk wins Twitter fight' and 'act...
# 2155  Twitter: Why Elon Musk has been so keen on tak...
# 2200           Four ways Elon Musk might change Twitter
# 2262  Elon Musk sells almost $4bn worth of Tesla shares
#
#                             pubDate  \
# 1340  Tue, 05 Apr 2022 13:19:05 GMT
# 1573  Mon, 11 Apr 2022 04:30:41 GMT
# 1738  Fri, 15 Apr 2022 03:40:31 GMT
# 1785  Fri, 15 Apr 2022 19:55:05 GMT
# 1937  Wed, 20 Apr 2022 23:45:33 GMT
# 2135  Mon, 25 Apr 2022 22:42:25 GMT
# 2148  Mon, 25 Apr 2022 23:40:31 GMT
# 2155  Mon, 25 Apr 2022 19:38:22 GMT
# ...

# %%
df_tesla.to_csv('datasets/bbc_tesla.csv', index=False)
